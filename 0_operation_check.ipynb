# %% [markdown]
# # Google Colaboratoryの動作確認/Checking the operation of Google Colaboratory

# %% [markdown]
# ## Google Colaboratory
#
# Google Colaboratory (以下，Colab.) はGoogleが提供するクラウド型のJupyter Notebook環境です．
# Google Colaboratory (Colab.) is a cloud-based Jupyter Notebook environment provided by Google.

# %% [markdown]
# ## 実行方法/execution method
# 実行はCodeセルの左にある実行ボタンをクリックすることで，一つづつ実行することができます．/Execution can be done one at a time by clicking the Run button to the left of the Code cell.
# また，実行したいセルを選択した状態で，`Shift + Enter`を押すことでも実行可能です．/It can also be done by pressing `Shift + Enter` while selecting the cell you want to execute.

# %% [markdown]
# ### 計算機のOS確認/Check the OS of the computer
# 下記のコードを実行してOSを確認．Run the following code to check the OS.

# %%
# !lsb_release -a
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 18.04.5 LTS
# Release:	18.04
# Codename:	bionic

# %% [markdown]
# ### ハードウェアの確認/Check hardware
#
# #### CPU
#
# 下記のプログラムを実行してCPU情報を確認．Run the following program to check the CPU information

# %%
# !cat /proc/cpuinfo | grep 'model name' | uniq
# !cat /proc/cpuinfo | grep 'processor' | uniq
# Out:
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# processor	: 0
# processor	: 1

# %% [markdown]
# #### メモリ/memory
#
# メモリの総容量と現在の使用状況はこのページの右上の「RAM」と表示されているアイコンにカーソルを重ねることでも，確認することができます．You can also check the total memory capacity and current usage by hovering the cursor over the icon labeled "RAM" in the upper right corner of this page.

# %%
# !cat /proc/meminfo | grep 'MemTotal'
# !cat /proc/meminfo | grep 'MemAvailable'
# Out:
# MemTotal:       13298572 kB
# MemAvailable:   12435860 kB

# %% [markdown]
# #### GPU
#
# 下記のプログラムを実行して，GPUの種類を確認します．
# 情報が表示されない場合は，**上部のメニューバーの「ランタイム」→「ランタイムのタイプを変更」からハードウェアアクセラレータをGPUにしてください．**
# Run the following program to check the GPU type.
# If the information is not displayed, select "Runtime" on the top menu bar, then "Change Runtime Type" and set the hardware accelerator to GPU.

# %%
# !nvidia-smi
# Out:
# Fri May 20 05:44:04 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P8    28W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
